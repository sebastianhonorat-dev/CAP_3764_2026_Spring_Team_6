# %% [markdown]
# # 05 Deployment Walkthrough
#
# This notebook gives a simple overview of the deployed prediction system.

# %% [markdown]
# ## What this notebook shows
#
# - how the saved XGBoost artifact is loaded
# - the model results table used in the project
# - the commands used to run FastAPI and Streamlit

# %%
from pathlib import Path
import sys

SRC_ROOT = Path('../src').resolve()
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from ira.modeling import load_predictor

predictor = load_predictor()
predictor.evaluation_table()

# %% [markdown]
# ## Run the deployed services
#
# FastAPI:
#
# ```powershell
# uvicorn ira.api:app --reload
# ```
#
# Streamlit:
#
# ```powershell
# streamlit run src/ira/streamlit_app.py
# ```
